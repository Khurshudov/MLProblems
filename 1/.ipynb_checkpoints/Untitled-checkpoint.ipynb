# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
milk = pd.read_csv('monthly-milk-production.csv',';', index_col=['month'], parse_dates=['month'], dayfirst=True)

# %%
milk.head()
# Out:
#             milk
# month
# 1962-01-01   589
# 1962-02-01   561
# 1962-03-01   640
# 1962-04-01   656
# 1962-05-01   727

# %%
sum([row / idx.days_in_month for idx, row in milk.iterrows()])
# Out:
# milk    4166.326662
# dtype: float64

# %%
plt.plot([row / idx.days_in_month for idx, row in milk.iterrows()])

# %%
plt.plot(milk)

# %%
import statsmodels.api as sm
sm.tsa.stattools.adfuller(milk.milk)
# Out:
# (-1.3038115874221248,
#  0.6274267086030337,
#  13,
#  154,
#  {'1%': -3.473542528196209,
#   '5%': -2.880497674144038,
#   '10%': -2.576878053634677},
#  1115.1730447395112)
